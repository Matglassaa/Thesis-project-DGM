# %% [markdown]
# # Postprocessing after training
#
# Import custom functions and define paths to datadirectories.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
from postprocessing import PostProcessing

gan_data_dir = Path(r"C:\Users\mathi\Desktop\TU Delft\TU Delft year 5\Master Thesis\Thesis-project-DGM\outputs\post_training\10000_training_samples\RUN_10000_samples_5_epochs_bs_64_val_size_015_one_hot_label_smoothing\realizations\*.npy")
real_data_dir = Path(r"C:\Users\mathi\Desktop\TU Delft\TU Delft year 5\Master Thesis\Thesis-project-DGM\datasets\training\setting_1_nexus_1000_samples_ntg_0.67_chdepth_6_isbx_100\samples\facies\*.npy")
output_dir = Path(r"C:\Users\mathi\Desktop\TU Delft\TU Delft year 5\Master Thesis\Thesis-project-DGM\plots\post_training_plots\RUN_10000_samples_5_epochs_bs_64_val_size_015_one_hot_label_smoothing")

# %% [markdown]
# ## Initialize postprocessing class

# %%
Postproc = PostProcessing(output_dir=output_dir,real_path=real_data_dir,gan_path=gan_data_dir, save_plots=True, num_samples=1000)

# %%
Postproc.plot_entropy()
# Out:
# --- Generating Entropy Matrices (100 Realizations) ---
# Saved XY entropy plot to: C:\Users\mathi\Desktop\TU Delft\TU Delft year 5\Master Thesis\Thesis-project-DGM\plots\post_training_plots\RUN_10000_samples_5_epochs_bs_64_val_size_015_one_hot_label_smoothing\entropy_matrix_XY_realizations_100_samples.png
# Saved ZX entropy plot to: C:\Users\mathi\Desktop\TU Delft\TU Delft year 5\Master Thesis\Thesis-project-DGM\plots\post_training_plots\RUN_10000_samples_5_epochs_bs_64_val_size_015_one_hot_label_smoothing\entropy_matrix_ZX_realizations_100_samples.png
# Saved ZY entropy plot to: C:\Users\mathi\Desktop\TU Delft\TU Delft year 5\Master Thesis\Thesis-project-DGM\plots\post_training_plots\RUN_10000_samples_5_epochs_bs_64_val_size_015_one_hot_label_smoothing\entropy_matrix_ZY_realizations_100_samples.png
